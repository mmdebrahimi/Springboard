# %%
import os
import pandas as pd
import numpy as np

# %%
os.getcwd()
# Out:
# 'C:\\Users\\emanu\\Downloads\\1481069814_relax_challenge\\relax_challenge'

# %%
df_eng = pd.read_csv('takehome_user_engagement.csv', parse_dates = True)
df = pd.read_csv('takehome_users.csv', encoding = "ISO-8859-1", parse_dates = True)
display(df_eng, df)

# with open('takehome_user_engagement.csv') as data:
#   df_engagement = pd.DataFrame(data)
#     data
# with open('takehome_users.csv') as main:
# #   df = pd.DataFrame(main)
#     print(main)
# Out:
#                  time_stamp  user_id  visited
# 0       2014-04-22 03:53:30        1        1
# 1       2013-11-15 03:45:04        2        1
# 2       2013-11-29 03:45:04        2        1
# 3       2013-12-09 03:45:04        2        1
# 4       2013-12-25 03:45:04        2        1
# ...                     ...      ...      ...
# 207912  2013-09-06 06:14:15    11996        1
# 207913  2013-01-15 18:28:37    11997        1
# 207914  2014-04-27 12:45:16    11998        1
# 207915  2012-06-02 11:55:59    11999        1
# 207916  2014-01-26 08:57:12    12000        1
#
# [207917 rows x 3 columns]
#        object_id        creation_time               name  \
# 0              1  2014-04-22 03:53:30     Clausen August
# 1              2  2013-11-15 03:45:04      Poole Matthew
# 2              3  2013-03-19 23:14:52  Bottrill Mitchell
# 3              4  2013-05-21 08:09:28    Clausen Nicklas
# 4              5  2013-01-17 10:14:20          Raw Grace
# ...

# %%
df.rename(columns={"object_id":"user_id"}, inplace = True)

# %%
df
# Out:
#        user_id        creation_time               name  \
# 0            1  2014-04-22 03:53:30     Clausen August
# 1            2  2013-11-15 03:45:04      Poole Matthew
# 2            3  2013-03-19 23:14:52  Bottrill Mitchell
# 3            4  2013-05-21 08:09:28    Clausen Nicklas
# 4            5  2013-01-17 10:14:20          Raw Grace
# ...        ...                  ...                ...
# 11995    11996  2013-09-06 06:14:15       Meier Sophia
# 11996    11997  2013-01-10 18:28:37      Fisher Amelie
# 11997    11998  2014-04-27 12:45:16        Haynes Jake
# 11998    11999  2012-05-31 11:55:59       Faber Annett
# 11999    12000  2014-01-26 08:57:12         Lima Thaís
#
#                             email     creation_source  \
# 0        AugustCClausen@yahoo.com        GUEST_INVITE
# 1          MatthewPoole@gustr.com          ORG_INVITE
# 2      MitchellBottrill@gustr.com          ORG_INVITE
# 3       NicklasSClausen@yahoo.com        GUEST_INVITE
# ...

# %%
df_eng = df_eng.drop_duplicates(subset = ['time_stamp'])

# %%
len(df_eng)
# Out:
# 207220

# %%
count1= list(zip(df_eng['user_id'], df_eng['user_id'].value_counts()))
print(count1[:10])
# np.set_printoptions(threshold=np.inf)
# print(np.sort(count))
# [(i, j) for i, j in count if i >= 3]
# Out:
# [(1, 606), (2, 600), (2, 593), (2, 590), (2, 585), (2, 581), (2, 580), (2, 566), (2, 547), (2, 545)]

# %%
df_eng['user_id']
# Out:
# 0             1.0
# 1             2.0
# 2             2.0
# 3             2.0
# 4             2.0
#            ...
# 207912    11996.0
# 207913    11997.0
# 207914    11998.0
# 207915    11999.0
# 207916    12000.0
# Name: user_id, Length: 207220, dtype: float32

# %%
os.getcwd()
# Out:
# 'C:\\Users\\emanu\\Downloads\\1481069814_relax_challenge\\relax_challenge'

# %%
df_eng['user_id'] = np.float32(df_eng['user_id'])
df_eng['visited'] = np.float32(df_eng['visited'])
df_eng.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 207220 entries, 0 to 207916
# Data columns (total 3 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   time_stamp  207220 non-null  object
#  1   user_id     207220 non-null  float32
#  2   visited     207220 non-null  float32
# dtypes: float32(2), object(1)
# memory usage: 4.7+ MB

# %%
# df_eng['time_stamp'] = pd.to_datetime(df_eng['time_stamp'])

# %%
df_eng.rename(columns={"time_stamp":"creation_time"}, inplace = True)

# %%
df.merge(df_eng, how = 'inner')
# Out:
#       user_id        creation_time               name  \
# 0           1  2014-04-22 03:53:30     Clausen August
# 1           2  2013-11-15 03:45:04      Poole Matthew
# 2           3  2013-03-19 23:14:52  Bottrill Mitchell
# 3          10  2013-01-16 22:08:03       Santos Carla
# 4          13  2014-03-30 16:19:38      Fry Alexander
# ...       ...                  ...                ...
# 4340    11987  2013-03-15 03:21:01         Reed Poppy
# 4341    11991  2014-04-20 14:22:45      Vaughn Arthur
# 4342    11996  2013-09-06 06:14:15       Meier Sophia
# 4343    11998  2014-04-27 12:45:16        Haynes Jake
# 4344    12000  2014-01-26 08:57:12         Lima Thaís
#
#                               email     creation_source  \
# 0          AugustCClausen@yahoo.com        GUEST_INVITE
# 1            MatthewPoole@gustr.com          ORG_INVITE
# 2        MitchellBottrill@gustr.com          ORG_INVITE
# 3     CarlaFerreiraSantos@gustr.com          ORG_INVITE
# ...

# %%
df_eng.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 207220 entries, 0 to 207916
# Data columns (total 3 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   creation_time  207220 non-null  object
#  1   user_id        207220 non-null  float32
#  2   visited        207220 non-null  float32
# dtypes: float32(2), object(1)
# memory usage: 4.7+ MB

# %%
#Divide df into shards because Jupyter keeps crashing in order to save on ram usage
df_shard = []
start_window = 0
end_window = len(df_eng)  + 1
n = 10 #number of divisions in the shard
end_shard = len(df_eng)/n


df_eng_shard = np.array_split(df_eng, 10)




# while (start_window + end_window < end_window):
#         moving_window = train[counter :moving_window_size + counter,:]
#         output_index = moving_window_size + counter +1
#         print(output_index)
#         ind = output[output_index]
        
#         new_output.append(ind)
#     #     print(new_output)


#         flatten_inp = moving_window.flatten()
#         flatten_input.append(flatten_inp)
#     #     output.append()
#     #     print(flatten_inp,"\n")
#     #       print(all_in_one.shape)

#         counter +=1

# #     print(len(new_output))
# #     print(len(flatten_input))
#     return flatten_input, new_output
# len(df_eng)/n

# %%
len(df_eng_shard), len(df_eng_shard[0])
# Out:
# (10, 20722)

# %%
df_eng_shard[0]
# Out:
#              creation_time  user_id  visited
# 0      2014-04-22 03:53:30      1.0      1.0
# 1      2013-11-15 03:45:04      2.0      1.0
# 2      2013-11-29 03:45:04      2.0      1.0
# 3      2013-12-09 03:45:04      2.0      1.0
# 4      2013-12-25 03:45:04      2.0      1.0
# ...                    ...      ...      ...
# 20717  2014-05-07 03:31:27   1235.0      1.0
# 20718  2014-05-14 03:31:27   1235.0      1.0
# 20719  2014-05-15 03:31:27   1235.0      1.0
# 20720  2014-05-16 03:31:27   1235.0      1.0
# 20721  2014-05-18 03:31:27   1235.0      1.0
#
# [20722 rows x 3 columns]

# %%
df.head()
# Out:
#    user_id        creation_time               name  \
# 0        1  2014-04-22 03:53:30     Clausen August
# 1        2  2013-11-15 03:45:04      Poole Matthew
# 2        3  2013-03-19 23:14:52  Bottrill Mitchell
# 3        4  2013-05-21 08:09:28    Clausen Nicklas
# 4        5  2013-01-17 10:14:20          Raw Grace
#
#                         email creation_source  last_session_creation_time  \
# 0    AugustCClausen@yahoo.com    GUEST_INVITE                1.398139e+09
# 1      MatthewPoole@gustr.com      ORG_INVITE                1.396238e+09
# 2  MitchellBottrill@gustr.com      ORG_INVITE                1.363735e+09
# 3   NicklasSClausen@yahoo.com    GUEST_INVITE                1.369210e+09
# 4          GraceRaw@yahoo.com    GUEST_INVITE                1.358850e+09
#
#    opted_in_to_mailing_list  enabled_for_marketing_drip  org_id  \
# 0                         1                           0      11
# 1                         0                           0       1
# ...

# %%
df['creation_time'].value_counts(ascending=False)
# Out:
# 2012-09-14 21:35:03    2
# 2013-05-25 04:35:52    2
# 2014-02-11 17:57:53    2
# 2012-09-01 07:22:09    2
# 2012-12-04 06:40:16    1
#                       ..
# 2014-05-28 08:44:08    1
# 2012-08-24 09:30:06    1
# 2013-02-03 20:33:38    1
# 2014-05-17 06:19:52    1
# 2013-03-21 12:04:08    1
# Name: creation_time, Length: 11996, dtype: int64

# %%
# df_eng_shard[0].pivot(columns= "user_id")[0:20].T
# Out:
#                                         0                    1   \
#               user_id
# creation_time 1.0      2014-04-22 03:53:30                  NaN
#               2.0                      NaN  2013-11-15 03:45:04
#               3.0                      NaN                  NaN
#               4.0                      NaN                  NaN
#               5.0                      NaN                  NaN
# ...                                    ...                  ...
# visited       1230.0                   NaN                  NaN
#               1232.0                   NaN                  NaN
#               1233.0                   NaN                  NaN
#               1234.0                   NaN                  NaN
#               1235.0                   NaN                  NaN
#
#                                         2                    3   \
#               user_id
# creation_time 1.0                      NaN                  NaN
# ...

# %%
# df_eng.pivot(columns= "user_id")

# %%
correlation = df.corr()
correlation
# Out:
#                              user_id  last_session_creation_time  \
# user_id                     1.000000                    0.015238
# last_session_creation_time  0.015238                    1.000000
# opted_in_to_mailing_list   -0.032370                    0.006590
# enabled_for_marketing_drip -0.022040                    0.008035
# org_id                      0.004110                    0.042203
# invited_by_user_id          0.018699                    0.011874
#
#                             opted_in_to_mailing_list  \
# user_id                                    -0.032370
# last_session_creation_time                  0.006590
# opted_in_to_mailing_list                    1.000000
# enabled_for_marketing_drip                  0.483529
# org_id                                      0.003432
# invited_by_user_id                          0.004699
#
#                             enabled_for_marketing_drip    org_id  \
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns
with sns.axes_style("white"):
    f, ax = plt.subplots(figsize=(25, 15))
    ax = sns.heatmap(correlation, square=True, cmap='RdYlGn')
# correlation = 

plt.plot()
plt.show()
