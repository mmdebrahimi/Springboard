# %% [markdown]
# <title>effects of keeping schools closed vs keeping them open -
# a comparative case study between Ontario when schools were closed and when they opened</title>
#
# In the academic year 2018/19, about 2.04 million students were enrolled in public elementary and secondary schools in Ontario. At this time, there were a total of around 4.92 million students enrolled in public elementary or secondary schools in Canada, a slight increase from previous years.Oct 19, 2020 (www.statista.com)
#
# As we know schools are a major breeding ground for the spread and growth of the seasonal flue, specially primary and pre-school grades where kids do not yet have a full understanding or control over health and safety measures necessary to keep the flue from spreading.
#
# In this case study we will look at the number of cases of covid in ontario and how it grew in the first few month until the schools started shutting down after March break(https://globalnews.ca/news/6668240/coronavirus-ontario-schools-closed/) and the trends since schools started reopening around September 8th

# %%
import urllib, json, requests
import pandas as pd

#get information from ontario governments online dataset
url = "https://covid-19.ontario.ca/covid-19-data/manifest.json"

response = urllib.request.urlopen(url)
data = json.loads(response.read())


chart = pd.read_html('https://en.wikipedia.org/wiki/COVID-19_pandemic_in_Canada')
# chart = pd.DataFrame(chart)
chart[2]
# Out:
# {'short_name': 'React App', 'name': 'Create React App Sample', 'icons': [{'src': 'favicon.ico', 'sizes': '64x64 32x32 24x24 16x16', 'type': 'image/x-icon'}, {'src': 'logo192.png', 'type': 'image/png', 'sizes': '192x192'}, {'src': 'logo512.png', 'type': 'image/png', 'sizes': '512x512'}], 'start_url': '.', 'display': 'standalone', 'theme_color': '#000000', 'background_color': '#ffffff'}
#    COVID-19 pandemic in Canada by province and territory, 2 December 2020 1905 UTC (vte)  \
#                                                                                 Province
# 0                                    British Columbia
# 1                                             Alberta
# 2                                        Saskatchewan
# 3                                            Manitoba
# 4                                             Ontario
# 5                                              Quebec
# 6                                       New Brunswick
# ...

# %% [markdown]
# Ontario is the most populous province in Canada with a population of roughly 14,711,827 people, followed by Quebec with roughly 8,537,674. As the pandemic started in 2020 the province of Quebec decided to keep schools open but implement safety measures where as Ontario started closing schools around mid March.

# %%
from PIL import Image

from IPython.display import Image
Image("Covid-Canada.png")

# %% [markdown]
# Now lets look at a chart from the Ontario government showing the number of cases in Ontario from the start of 1/26/2020

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %%
pd.read_csv('covidtesting.csv', parse_dates = True)
# Out:
#     Reported Date  Confirmed Negative  Presumptive Negative  \
# 0       1/26/2020                 NaN                   NaN
# 1       1/27/2020                 NaN                   NaN
# 2       1/28/2020                 NaN                   NaN
# 3       1/30/2020                 NaN                   NaN
# 4       1/31/2020                 NaN                   NaN
# 5        2/3/2020                 NaN                   NaN
# 6        2/4/2020                90.0                  12.0
# 7        2/5/2020                96.0                   8.0
# 8        2/6/2020               104.0                   0.0
# 9        2/8/2020               130.0                  25.0
# 10      2/10/2020               167.0                  81.0
# 11      2/11/2020               184.0                  79.0
# 12      2/12/2020               257.0                  44.0
# 13      2/13/2020               306.0                  16.0
# 14      2/14/2020               353.0                   0.0
# ...
